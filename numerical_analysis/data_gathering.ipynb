# %%
import pickle
with open("api_key.txt", "rb") as input_file:
  key = pickle.load(input_file)

# %%
import urllib, json
import requests
from urllib.request import urlopen
import pandas as pd

# Function to get the Data

def get_jsonparsed_data(url):
    res = urlopen(url)
    data = res.read().decode("utf-8")
    return json.loads(data)

# %%
df = get_jsonparsed_data("https://financialmodelingprep.com/api/v3/historical-price-full/AAPL?from=1995-01-01&to=2024-01-01&apikey={}".format(key))
df1 = pd.DataFrame(df['historical'])
df1
# Out:
#             date       open  ...            label  changeOverTime
# 0     2023-12-29  193.90000  ...  December 29, 23       -0.007065
# 1     2023-12-28  194.14000  ...  December 28, 23       -0.002884
# 2     2023-12-27  192.49000  ...  December 27, 23        0.003429
# 3     2023-12-26  193.61000  ...  December 26, 23       -0.002892
# 4     2023-12-22  195.18000  ...  December 22, 23       -0.008095
# ...          ...        ...  ...              ...             ...
# 7295  1995-01-09    0.37165  ...   January 09, 95       -0.010100
# 7296  1995-01-06    0.37165  ...   January 06, 95        0.009014
# 7297  1995-01-05    0.35045  ...   January 05, 95       -0.009559
# 7298  1995-01-04    0.34487  ...   January 04, 95        0.019400
# 7299  1995-01-03    0.34710  ...   January 03, 95       -0.012900
#
# [7300 rows x 13 columns]

# %%
sp500 = pd.read_csv('sp500.csv')
sp500['date'] = pd.to_datetime(sp500['date'])
sp500.set_index('date', inplace=True)
sp500
# Out:
#                                                       tickers
# date
# 1996-01-02  AAL,AAMRQ,AAPL,ABI,ABS,ABT,ABX,ACKH,ACV,ADM,AD...
# 1996-01-03  AAL,AAMRQ,AAPL,ABI,ABS,ABT,ABX,ACKH,ACV,ADM,AD...
# 1996-01-04  AAL,AAMRQ,AAPL,ABI,ABS,ABT,ABX,ACKH,ACV,ADM,AD...
# 1996-01-10  AAL,AAMRQ,AAPL,ABI,ABS,ABT,ABX,ACKH,ACV,ADM,AD...
# 1996-01-11  AAL,AAMRQ,AAPL,ABI,ABS,ABT,ABX,ACKH,ACV,ADM,AD...
# ...                                                       ...
# 2023-08-25  A,AAL,AAPL,ABBV,ABC,ABT,ACGL,ACN,ADBE,ADI,ADM,...
# 2023-08-30  A,AAL,AAPL,ABBV,ABT,ACGL,ACN,ADBE,ADI,ADM,ADP,...
# 2023-09-18  A,AAL,AAPL,ABBV,ABNB,ABT,ACGL,ACN,ADBE,ADI,ADM...
# 2023-10-02  A,AAL,AAPL,ABBV,ABNB,ABT,ACGL,ACN,ADBE,ADI,ADM...
# 2023-10-18  A,AAL,AAPL,ABBV,ABNB,ABT,ACGL,ACN,ADBE,ADI,ADM...
#
# [2676 rows x 1 columns]

# %%
all_tickers = set()
for idx, _ in enumerate(sp500.index):
    all_tickers = all_tickers.union(set(sp_constituents.iloc[idx].tickers.split(',')))

# %%
import datetime as dt
from tqdm import tqdm
tickers_per_date = pd.DataFrame(columns=list(all_tickers), index=sp500.index)
for ticker in tqdm(all_tickers):
    found = False
    tickers_per_date[ticker] = sp500['tickers'].str.contains(ticker)
# Out:
# 100%|██████████| 1156/1156 [00:23<00:00, 48.18it/s]

# %%
tickers_per_date[tickers_per_date['AAPL']].index
# Out:
# DatetimeIndex(['1996-01-02', '1996-01-03', '1996-01-04', '1996-01-10',
#                '1996-01-11', '1996-01-12', '1996-01-22', '1996-01-23',
#                '1996-01-24', '1996-01-30',
#                ...
#                '2023-05-04', '2023-05-16', '2023-06-07', '2023-06-10',
#                '2023-06-20', '2023-08-25', '2023-08-30', '2023-09-18',
#                '2023-10-02', '2023-10-18'],
#               dtype='datetime64[ns]', name='date', length=2676, freq=None)

# %%
tickers_per_date
# Out:
#               CFG    ICE    RRC   CCI   HES  ...    CGP    KBH    CLF    ACN  EKDKQ
# date                                         ...
# 1996-01-02  False  False  False  True  True  ...   True   True   True  False   True
# 1996-01-03  False  False  False  True  True  ...   True   True   True  False   True
# 1996-01-04  False  False  False  True  True  ...   True   True   True  False   True
# 1996-01-10  False  False  False  True  True  ...   True   True   True  False   True
# 1996-01-11  False  False  False  True  True  ...   True   True   True  False   True
# ...           ...    ...    ...   ...   ...  ...    ...    ...    ...    ...    ...
# 2023-08-25   True   True  False  True  True  ...  False  False  False   True  False
# 2023-08-30   True   True  False  True  True  ...  False  False  False   True  False
# 2023-09-18   True   True  False  True  True  ...  False  False  False   True  False
# 2023-10-02   True   True  False  True  True  ...  False  False  False   True  False
# ...
